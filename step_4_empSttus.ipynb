# %%
import urllib
import json
api_key = 'xxx'

# %%
import pandas as pd

df = pd.read_csv('corp_code.csv', dtype=str)
print(len(df))
df = df[df['corp_name'].str.contains("LG")]
df
# Out:
# 3237
#      corp_code corp_name stock_code
# 99    00318617     LG파워콤     045820
# 131   00105767    LG마이크론     016990
# 375   00120100    LG석유화학     012990
# 484   00423609    LG생명과학     068870
# 819   00356370    LG생활건강     051900
# 932   00120021        LG     003550
# 1049  00120076      LG상사     001120
# 1377  00231363    LG유플러스     032640
# 1477  00105961     LG이노텍     011070
# 1869  00222532    LG헬로비전     037560
# 2021  00356361      LG화학     051910
# 2197  00759513    LG하우시스     108670
# 2214  00105873   LG디스플레이     034220
# 2224  00401731      LG전자     066570

# %%
# 단일회사 주요계정

account_step2_df = pd.DataFrame(columns=["corp_name", "corp_code", "bsns_year", "reprt_code", "data"])

for index, row in df.iterrows():
    for bsns_year in range(2020, 2014, -1):
        for reprt_code in ['11011', '11012']:
            api_url = 'https://opendart.fss.or.kr/api/empSttus.json'
            api_url = api_url + '?' + 'crtfc_key={}'.format(api_key)
            api_url = api_url + '&' + 'corp_code={}'.format(row["corp_code"])
            api_url = api_url + '&' + 'bsns_year={}'.format(bsns_year)
            api_url = api_url + '&' + 'reprt_code={}'.format(reprt_code)

            response = urllib.request.urlopen(api_url)
            data = response.read().decode('UTF-8')
            new_row = {
                "corp_name": row["corp_name"],
                "corp_code": row["corp_code"],
                "bsns_year": bsns_year,
                "reprt_code": reprt_code,
                "data": data,
            }
            account_step2_df = account_step2_df.append(new_row, ignore_index=True)

account_step2_df.to_csv('step4_df.csv', index=False)
account_step2_df
# Out:
#     corp_name corp_code bsns_year reprt_code  \
# 0       LG파워콤  00318617      2020      11011
# 1       LG파워콤  00318617      2020      11012
# 2       LG파워콤  00318617      2019      11011
# 3       LG파워콤  00318617      2019      11012
# 4       LG파워콤  00318617      2018      11011
# 5       LG파워콤  00318617      2018      11012
# 6       LG파워콤  00318617      2017      11011
# 7       LG파워콤  00318617      2017      11012
# 8       LG파워콤  00318617      2016      11011
# 9       LG파워콤  00318617      2016      11012
# 10      LG파워콤  00318617      2015      11011
# 11      LG파워콤  00318617      2015      11012
# 12     LG마이크론  00105767      2020      11011
# 13     LG마이크론  00105767      2020      11012
# 14     LG마이크론  00105767      2019      11011
# 15     LG마이크론  00105767      2019      11012
# 16     LG마이크론  00105767      2018      11011
# 17     LG마이크론  00105767      2018      11012
# 18     LG마이크론  00105767      2017      11011
# 19     LG마이크론  00105767      2017      11012
# 20     LG마이크론  00105767      2016      11011
# 21     LG마이크론  00105767      2016      11012
# 22     LG마이크론  00105767      2015      11011
# 23     LG마이크론  00105767      2015      11012
# 24     LG석유화학  00120100      2020      11011
# 25     LG석유화학  00120100      2020      11012
# 26     LG석유화학  00120100      2019      11011
# 27     LG석유화학  00120100      2019      11012
# 28     LG석유화학  00120100      2018      11011
# 29     LG석유화학  00120100      2018      11012
# ..        ...       ...       ...        ...
# 138    LG하우시스  00759513      2017      11011
# 139    LG하우시스  00759513      2017      11012
# 140    LG하우시스  00759513      2016      11011
# 141    LG하우시스  00759513      2016      11012
# 142    LG하우시스  00759513      2015      11011
# 143    LG하우시스  00759513      2015      11012
# 144   LG디스플레이  00105873      2020      11011
# 145   LG디스플레이  00105873      2020      11012
# 146   LG디스플레이  00105873      2019      11011
# 147   LG디스플레이  00105873      2019      11012
# 148   LG디스플레이  00105873      2018      11011
# 149   LG디스플레이  00105873      2018      11012
# 150   LG디스플레이  00105873      2017      11011
# 151   LG디스플레이  00105873      2017      11012
# 152   LG디스플레이  00105873      2016      11011
# 153   LG디스플레이  00105873      2016      11012
# 154   LG디스플레이  00105873      2015      11011
# 155   LG디스플레이  00105873      2015      11012
# 156      LG전자  00401731      2020      11011
# 157      LG전자  00401731      2020      11012
# 158      LG전자  00401731      2019      11011
# 159      LG전자  00401731      2019      11012
# 160      LG전자  00401731      2018      11011
# 161      LG전자  00401731      2018      11012
# 162      LG전자  00401731      2017      11011
# 163      LG전자  00401731      2017      11012
# 164      LG전자  00401731      2016      11011
# 165      LG전자  00401731      2016      11012
# 166      LG전자  00401731      2015      11011
# 167      LG전자  00401731      2015      11012
#
#                                                   data
# 0          {"status":"013","message":"조회된 데이타가 없습니다."}
# 1          {"status":"013","message":"조회된 데이타가 없습니다."}
# 2          {"status":"013","message":"조회된 데이타가 없습니다."}
# 3          {"status":"013","message":"조회된 데이타가 없습니다."}
# 4          {"status":"013","message":"조회된 데이타가 없습니다."}
# 5          {"status":"013","message":"조회된 데이타가 없습니다."}
# 6          {"status":"013","message":"조회된 데이타가 없습니다."}
# 7          {"status":"013","message":"조회된 데이타가 없습니다."}
# 8          {"status":"013","message":"조회된 데이타가 없습니다."}
# 9          {"status":"013","message":"조회된 데이타가 없습니다."}
# 10         {"status":"013","message":"조회된 데이타가 없습니다."}
# 11         {"status":"013","message":"조회된 데이타가 없습니다."}
# 12         {"status":"013","message":"조회된 데이타가 없습니다."}
# 13         {"status":"013","message":"조회된 데이타가 없습니다."}
# 14         {"status":"013","message":"조회된 데이타가 없습니다."}
# 15         {"status":"013","message":"조회된 데이타가 없습니다."}
# 16         {"status":"013","message":"조회된 데이타가 없습니다."}
# 17         {"status":"013","message":"조회된 데이타가 없습니다."}
# 18         {"status":"013","message":"조회된 데이타가 없습니다."}
# 19         {"status":"013","message":"조회된 데이타가 없습니다."}
# 20         {"status":"013","message":"조회된 데이타가 없습니다."}
# 21         {"status":"013","message":"조회된 데이타가 없습니다."}
# 22         {"status":"013","message":"조회된 데이타가 없습니다."}
# 23         {"status":"013","message":"조회된 데이타가 없습니다."}
# 24         {"status":"013","message":"조회된 데이타가 없습니다."}
# 25         {"status":"013","message":"조회된 데이타가 없습니다."}
# 26         {"status":"013","message":"조회된 데이타가 없습니다."}
# 27         {"status":"013","message":"조회된 데이타가 없습니다."}
# 28         {"status":"013","message":"조회된 데이타가 없습니다."}
# 29         {"status":"013","message":"조회된 데이타가 없습니다."}
# ..                                                 ...
# 138  {"status":"000","message":"정상","list":[{"rcept...
# 139  {"status":"000","message":"정상","list":[{"rcept...
# 140  {"status":"000","message":"정상","list":[{"rcept...
# 141  {"status":"000","message":"정상","list":[{"rcept...
# 142  {"status":"000","message":"정상","list":[{"rcept...
# 143  {"status":"000","message":"정상","list":[{"rcept...
# 144        {"status":"013","message":"조회된 데이타가 없습니다."}
# 145  {"status":"000","message":"정상","list":[{"rcept...
# 146  {"status":"000","message":"정상","list":[{"rcept...
# 147  {"status":"000","message":"정상","list":[{"rcept...
# 148  {"status":"000","message":"정상","list":[{"rcept...
# 149  {"status":"000","message":"정상","list":[{"rcept...
# 150  {"status":"000","message":"정상","list":[{"rcept...
# 151  {"status":"000","message":"정상","list":[{"rcept...
# 152  {"status":"000","message":"정상","list":[{"rcept...
# 153  {"status":"000","message":"정상","list":[{"rcept...
# 154  {"status":"000","message":"정상","list":[{"rcept...
# 155  {"status":"000","message":"정상","list":[{"rcept...
# 156        {"status":"013","message":"조회된 데이타가 없습니다."}
# 157  {"status":"000","message":"정상","list":[{"rcept...
# 158  {"status":"000","message":"정상","list":[{"rcept...
# 159  {"status":"000","message":"정상","list":[{"rcept...
# 160  {"status":"000","message":"정상","list":[{"rcept...
# 161  {"status":"000","message":"정상","list":[{"rcept...
# 162  {"status":"000","message":"정상","list":[{"rcept...
# 163  {"status":"000","message":"정상","list":[{"rcept...
# 164  {"status":"000","message":"정상","list":[{"rcept...
# 165  {"status":"000","message":"정상","list":[{"rcept...
# 166  {"status":"000","message":"정상","list":[{"rcept...
# 167  {"status":"000","message":"정상","list":[{"rcept...
#
# [168 rows x 5 columns]
